# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/LoanStats.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>int_rate</th><th>loan_amnt</th><th>term</th><th>grade</th><th>home_ownership</th><th>annual_inc</th><th>purpose</th></tr></thead><tbody><tr><td>10.65</td><td>5000</td><td>36</td><td>B</td><td>RENT</td><td>24000</td><td>credit_card</td></tr><tr><td>15.27</td><td>2500</td><td>60</td><td>C</td><td>RENT</td><td>30000</td><td>car</td></tr><tr><td>15.96</td><td>2400</td><td>36</td><td>C</td><td>RENT</td><td>12252</td><td>small_business</td></tr><tr><td>13.49</td><td>10000</td><td>36</td><td>C</td><td>RENT</td><td>49200</td><td>other</td></tr><tr><td>12.69</td><td>3000</td><td>60</td><td>B</td><td>RENT</td><td>80000</td><td>other</td></tr><tr><td>7.90</td><td>5000</td><td>36</td><td>A</td><td>RENT</td><td>36000</td><td>wedding</td></tr><tr><td>15.96</td><td>7000</td><td>60</td><td>C</td><td>RENT</td><td>47004</td><td>debt_consolidation</td></tr><tr><td>18.64</td><td>3000</td><td>36</td><td>E</td><td>RENT</td><td>48000</td><td>car</td></tr><tr><td>21.28</td><td>5600</td><td>60</td><td>F</td><td>OWN</td><td>40000</td><td>small_business</td></tr><tr><td>12.69</td><td>5375</td><td>60</td><td>B</td><td>RENT</td><td>15000</td><td>other</td></tr><tr><td>14.65</td><td>6500</td><td>60</td><td>C</td><td>OWN</td><td>72000</td><td>debt_consolidation</td></tr><tr><td>12.69</td><td>12000</td><td>36</td><td>B</td><td>OWN</td><td>75000</td><td>debt_consolidation</td></tr><tr><td>13.49</td><td>9000</td><td>36</td><td>C</td><td>RENT</td><td>30000</td><td>debt_consolidation</td></tr><tr><td>9.91</td><td>3000</td><td>36</td><td>B</td><td>RENT</td><td>15000</td><td>credit_card</td></tr><tr><td>10.65</td><td>10000</td><td>36</td><td>B</td><td>RENT</td><td>100000</td><td>other</td></tr><tr><td>16.29</td><td>1000</td><td>36</td><td>D</td><td>RENT</td><td>28000</td><td>debt_consolidation</td></tr><tr><td>15.27</td><td>10000</td><td>36</td><td>C</td><td>RENT</td><td>42000</td><td>home_improvement</td></tr><tr><td>6.03</td><td>3600</td><td>36</td><td>A</td><td>MORTGAGE</td><td>110000</td><td>major_purchase</td></tr><tr><td>11.71</td><td>6000</td><td>36</td><td>B</td><td>MORTGAGE</td><td>84000</td><td>medical</td></tr><tr><td>6.03</td><td>9200</td><td>36</td><td>A</td><td>RENT</td><td>77385.19</td><td>debt_consolidation</td></tr><tr><td>15.27</td><td>20250</td><td>60</td><td>C</td><td>RENT</td><td>43370</td><td>debt_consolidation</td></tr><tr><td>12.42</td><td>21000</td><td>36</td><td>B</td><td>RENT</td><td>105000</td><td>debt_consolidation</td></tr><tr><td>11.71</td><td>10000</td><td>36</td><td>B</td><td>OWN</td><td>50000</td><td>credit_card</td></tr><tr><td>11.71</td><td>10000</td><td>36</td><td>B</td><td>RENT</td><td>50000</td><td>debt_consolidation</td></tr><tr><td>11.71</td><td>6000</td><td>36</td><td>B</td><td>RENT</td><td>76000</td><td>major_purchase</td></tr><tr><td>9.91</td><td>15000</td><td>36</td><td>B</td><td>MORTGAGE</td><td>92000</td><td>credit_card</td></tr><tr><td>14.27</td><td>15000</td><td>36</td><td>C</td><td>RENT</td><td>60000</td><td>debt_consolidation</td></tr><tr><td>16.77</td><td>5000</td><td>60</td><td>D</td><td>RENT</td><td>50004</td><td>other</td></tr><tr><td>11.71</td><td>4000</td><td>36</td><td>B</td><td>MORTGAGE</td><td>106000</td><td>debt_consolidation</td></tr><tr><td>11.71</td><td>8500</td><td>36</td><td>B</td><td>RENT</td><td>25000</td><td>credit_card</td></tr><tr><td>7.51</td><td>4375</td><td>36</td><td>A</td><td>MORTGAGE</td><td>17108</td><td>debt_consolidation</td></tr><tr><td>7.90</td><td>31825</td><td>36</td><td>A</td><td>MORTGAGE</td><td>75000</td><td>debt_consolidation</td></tr><tr><td>15.96</td><td>10000</td><td>60</td><td>C</td><td>RENT</td><td>29120</td><td>debt_consolidation</td></tr><tr><td>8.90</td><td>5000</td><td>36</td><td>A</td><td>RENT</td><td>24044</td><td>debt_consolidation</td></tr><tr><td>15.96</td><td>7000</td><td>36</td><td>C</td><td>RENT</td><td>34000</td><td>credit_card</td></tr><tr><t ...

# %%
# Create a view or table
df.createOrReplaceTempView("LoanStats")

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `LoanStats`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>int_rate</th><th>loan_amnt</th><th>term</th><th>grade</th><th>home_ownership</th><th>annual_inc</th><th>purpose</th></tr></thead><tbody><tr><td>10.65</td><td>5000</td><td>36</td><td>B</td><td>RENT</td><td>24000</td><td>credit_card</td></tr><tr><td>15.27</td><td>2500</td><td>60</td><td>C</td><td>RENT</td><td>30000</td><td>car</td></tr><tr><td>15.96</td><td>2400</td><td>36</td><td>C</td><td>RENT</td><td>12252</td><td>small_business</td></tr><tr><td>13.49</td><td>10000</td><td>36</td><td>C</td><td>RENT</td><td>49200</td><td>other</td></tr><tr><td>12.69</td><td>3000</td><td>60</td><td>B</td><td>RENT</td><td>80000</td><td>other</td></tr><tr><td>7.90</td><td>5000</td><td>36</td><td>A</td><td>RENT</td><td>36000</td><td>wedding</td></tr><tr><td>15.96</td><td>7000</td><td>60</td><td>C</td><td>RENT</td><td>47004</td><td>debt_consolidation</td></tr><tr><td>18.64</td><td>3000</td><td>36</td><td>E</td><td>RENT</td><td>48000</td><td>car</td></tr><tr><td>21.28</td><td>5600</td><td>60</td><td>F</td><td>OWN</td><td>40000</td><td>small_business</td></tr><tr><td>12.69</td><td>5375</td><td>60</td><td>B</td><td>RENT</td><td>15000</td><td>other</td></tr><tr><td>14.65</td><td>6500</td><td>60</td><td>C</td><td>OWN</td><td>72000</td><td>debt_consolidation</td></tr><tr><td>12.69</td><td>12000</td><td>36</td><td>B</td><td>OWN</td><td>75000</td><td>debt_consolidation</td></tr><tr><td>13.49</td><td>9000</td><td>36</td><td>C</td><td>RENT</td><td>30000</td><td>debt_consolidation</td></tr><tr><td>9.91</td><td>3000</td><td>36</td><td>B</td><td>RENT</td><td>15000</td><td>credit_card</td></tr><tr><td>10.65</td><td>10000</td><td>36</td><td>B</td><td>RENT</td><td>100000</td><td>other</td></tr><tr><td>16.29</td><td>1000</td><td>36</td><td>D</td><td>RENT</td><td>28000</td><td>debt_consolidation</td></tr><tr><td>15.27</td><td>10000</td><td>36</td><td>C</td><td>RENT</td><td>42000</td><td>home_improvement</td></tr><tr><td>6.03</td><td>3600</td><td>36</td><td>A</td><td>MORTGAGE</td><td>110000</td><td>major_purchase</td></tr><tr><td>11.71</td><td>6000</td><td>36</td><td>B</td><td>MORTGAGE</td><td>84000</td><td>medical</td></tr><tr><td>6.03</td><td>9200</td><td>36</td><td>A</td><td>RENT</td><td>77385.19</td><td>debt_consolidation</td></tr><tr><td>15.27</td><td>20250</td><td>60</td><td>C</td><td>RENT</td><td>43370</td><td>debt_consolidation</td></tr><tr><td>12.42</td><td>21000</td><td>36</td><td>B</td><td>RENT</td><td>105000</td><td>debt_consolidation</td></tr><tr><td>11.71</td><td>10000</td><td>36</td><td>B</td><td>OWN</td><td>50000</td><td>credit_card</td></tr><tr><td>11.71</td><td>10000</td><td>36</td><td>B</td><td>RENT</td><td>50000</td><td>debt_consolidation</td></tr><tr><td>11.71</td><td>6000</td><td>36</td><td>B</td><td>RENT</td><td>76000</td><td>major_purchase</td></tr><tr><td>9.91</td><td>15000</td><td>36</td><td>B</td><td>MORTGAGE</td><td>92000</td><td>credit_card</td></tr><tr><td>14.27</td><td>15000</td><td>36</td><td>C</td><td>RENT</td><td>60000</td><td>debt_consolidation</td></tr><tr><td>16.77</td><td>5000</td><td>60</td><td>D</td><td>RENT</td><td>50004</td><td>other</td></tr><tr><td>11.71</td><td>4000</td><td>36</td><td>B</td><td>MORTGAGE</td><td>106000</td><td>debt_consolidation</td></tr><tr><td>11.71</td><td>8500</td><td>36</td><td>B</td><td>RENT</td><td>25000</td><td>credit_card</td></tr><tr><td>7.51</td><td>4375</td><td>36</td><td>A</td><td>MORTGAGE</td><td>17108</td><td>debt_consolidation</td></tr><tr><td>7.90</td><td>31825</td><td>36</td><td>A</td><td>MORTGAGE</td><td>75000</td><td>debt_consolidation</td></tr><tr><td>15.96</td><td>10000</td><td>60</td><td>C</td><td>RENT</td><td>29120</td><td>debt_consolidation</td></tr><tr><td>8.90</td><td>5000</td><td>36</td><td>A</td><td>RENT</td><td>24044</td><td>debt_consolidation</td></tr><tr><td>15.96</td><td>7000</td><td>36</td><td>C</td><td>RENT</td><td>34000</td><td>credit_card</td></tr><tr><t ...

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "loan"

df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-1380537995866843> in <module>
#       5 permanent_table_name = "loan"
#       6
# ----> 7 df.write.format("parquet").saveAsTable(permanent_table_name)
#
# /databricks/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#     804         if format is not None:
#     805             self.format(format)
# --> 806         self._jwrite.saveAsTable(name)
#     807
#     808     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: Table `loan` already exists.

# %%
df.head()
# Out:
# Out[10]: Row(int_rate='10.65', loan_amnt='5000', term='36', grade='B', home_ownership='RENT', annual_inc='24000', purpose='credit_card')

# %%
# %python

import pandas as pd

# %%
df.printSchema()
# Out:
# root
#  |-- int_rate: string (nullable = true)
#  |-- loan_amnt: string (nullable = true)
#  |-- term: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: string (nullable = true)
#  |-- purpose: string (nullable = true)

# %%
from pyspark.sql.types import IntegerType,FloatType
df = df.withColumn("int_rate", df["int_rate"].cast(FloatType()))
df = df.withColumn("loan_amnt", df["loan_amnt"].cast(IntegerType()))
df = df.withColumn("term", df["term"].cast(IntegerType()))
df = df.withColumn("annual_inc", df["annual_inc"].cast(IntegerType()))
df.printSchema()
# Out:
# root
#  |-- int_rate: float (nullable = true)
#  |-- loan_amnt: integer (nullable = true)
#  |-- term: integer (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: integer (nullable = true)
#  |-- purpose: string (nullable = true)

# %%
import pandas as pd
numeric_features = [t[0] for t in df.dtypes if t[1] == 'int' or t[1] == 'double']
sampled_data = df.select(numeric_features).sample(False, 0.8).toPandas()
axs = pd.scatter_matrix(sampled_data, figsize=(10, 10))
n = len(sampled_data.columns)
for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n-1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-1231047598254650> in <module>
#       2 numeric_features = [t[0] for t in df.dtypes if t[1] == 'int' or t[1] == 'double']
#       3 sampled_data = df.select(numeric_features).sample(False, 0.8).toPandas()
# ----> 4 axs = pd.scatter_matrix(sampled_data, figsize=(10, 10))
#       5 n = len(sampled_data.columns)
#       6 for i in range(n):
#
# /databricks/python/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'scatter_matrix'

# %%
import six
for i in df.columns:
    if not( isinstance(df.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to int_rate for ", i, df.stat.corr('int_rate',i))
# Out:
# Correlation to int_rate for  int_rate 1.0
# Correlation to int_rate for  loan_amnt 0.31048061154458356
# Correlation to int_rate for  term 0.45288430934663326
# Correlation to int_rate for  annual_inc 0.05348537726567628

# %%
# Let us use the StringIndexer
from pyspark.ml.feature import StringIndexer
# Step 1: configure the object: We will built an object with some attributes
indexer = StringIndexer(inputCol='grade', outputCol="gradeNumeric")
indexer_fitted = indexer.fit(df)
df_indexed = indexer_fitted.transform(df)
df_indexed.show()
# Out:
# +--------+---------+----+-----+--------------+----------+------------------+------------+
# |int_rate|loan_amnt|term|grade|home_ownership|annual_inc|           purpose|gradeNumeric|
# +--------+---------+----+-----+--------------+----------+------------------+------------+
# |   10.65|     5000|  36|    B|          RENT|     24000|       credit_card|         0.0|
# |   15.27|     2500|  60|    C|          RENT|     30000|               car|         2.0|
# |   15.96|     2400|  36|    C|          RENT|     12252|    small_business|         2.0|
# |   13.49|    10000|  36|    C|          RENT|     49200|             other|         2.0|
# |   12.69|     3000|  60|    B|          RENT|     80000|             other|         0.0|
# |     7.9|     5000|  36|    A|          RENT|     36000|           wedding|         1.0|
# |   15.96|     7000|  60|    C|          RENT|     47004|debt_consolidation|         2.0|
# |   18.64|     3000|  36|    E|          RENT|     48000|               car|         4.0|
# |   21.28|     5600|  60|    F|           OWN|     40000|    small_business|         5.0|
# |   12.69|     5375|  60|    B|          RENT|     15000|             other|         0.0|
# |   14.65|     6500|  60|    C|           OWN|     72000|debt_consolidation|         2.0|
# |   12.69|    12000|  36|    B|           OWN|     75000|debt_consolidation|         0.0|
# |   13.49|     9000|  36|    C|          RENT|     30000|debt_consolidation|         2.0|
# |    9.91|     3000|  36|    B|          RENT|     15000|       credit_card|         0.0|
# |   10.65|    10000|  36|    B|          RENT|    100000|             other|         0.0|
# |   16.29|     1000|  36|    D|          RENT|     28000|debt_consolidation|         3.0|
# |   15.27|    10000|  36|    C|          RENT|     42000|  home_improvement|         2.0|
# |    6.03|     3600|  36|    A|      MORTGAGE|    110000|    major_purchase|         1.0|
# |   11.71|     6000|  36|    B|      MORTGAGE|     84000|           medical|         0.0|
# |    6.03|     9200|  36|    A|          RENT|     77385|debt_consolidation|         1.0|
# +--------+---------+----+-----+--------------+----------+------------------+------------+
# only showing top 20 rows

# %%
# Step 1: configure the object: We will built an object with some attributes
indexer1 = StringIndexer(inputCol='home_ownership', outputCol="ownershipNumeric")
indexer_fitted1 = indexer1.fit(df_indexed)
df_indexed1 = indexer_fitted1.transform(df_indexed)
df_indexed1.show()
# Out:
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+
# |int_rate|loan_amnt|term|grade|home_ownership|annual_inc|           purpose|gradeNumeric|ownershipNumeric|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+
# |   10.65|     5000|  36|    B|          RENT|     24000|       credit_card|         0.0|             0.0|
# |   15.27|     2500|  60|    C|          RENT|     30000|               car|         2.0|             0.0|
# |   15.96|     2400|  36|    C|          RENT|     12252|    small_business|         2.0|             0.0|
# |   13.49|    10000|  36|    C|          RENT|     49200|             other|         2.0|             0.0|
# |   12.69|     3000|  60|    B|          RENT|     80000|             other|         0.0|             0.0|
# |     7.9|     5000|  36|    A|          RENT|     36000|           wedding|         1.0|             0.0|
# |   15.96|     7000|  60|    C|          RENT|     47004|debt_consolidation|         2.0|             0.0|
# |   18.64|     3000|  36|    E|          RENT|     48000|               car|         4.0|             0.0|
# |   21.28|     5600|  60|    F|           OWN|     40000|    small_business|         5.0|             2.0|
# |   12.69|     5375|  60|    B|          RENT|     15000|             other|         0.0|             0.0|
# |   14.65|     6500|  60|    C|           OWN|     72000|debt_consolidation|         2.0|             2.0|
# |   12.69|    12000|  36|    B|           OWN|     75000|debt_consolidation|         0.0|             2.0|
# |   13.49|     9000|  36|    C|          RENT|     30000|debt_consolidation|         2.0|             0.0|
# |    9.91|     3000|  36|    B|          RENT|     15000|       credit_card|         0.0|             0.0|
# |   10.65|    10000|  36|    B|          RENT|    100000|             other|         0.0|             0.0|
# |   16.29|     1000|  36|    D|          RENT|     28000|debt_consolidation|         3.0|             0.0|
# |   15.27|    10000|  36|    C|          RENT|     42000|  home_improvement|         2.0|             0.0|
# |    6.03|     3600|  36|    A|      MORTGAGE|    110000|    major_purchase|         1.0|             1.0|
# |   11.71|     6000|  36|    B|      MORTGAGE|     84000|           medical|         0.0|             1.0|
# |    6.03|     9200|  36|    A|          RENT|     77385|debt_consolidation|         1.0|             0.0|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+
# only showing top 20 rows

# %%
# Step 1: configure the object: We will built an object with some attributes
indexer2 = StringIndexer(inputCol='purpose', outputCol="purposeNumeric")
indexer_fitted2 = indexer2.fit(df_indexed1)
df_indexed2 = indexer_fitted2.transform(df_indexed1)
df_indexed2.show()
# Out:
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+
# |int_rate|loan_amnt|term|grade|home_ownership|annual_inc|           purpose|gradeNumeric|ownershipNumeric|purposeNumeric|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+
# |   10.65|     5000|  36|    B|          RENT|     24000|       credit_card|         0.0|             0.0|           1.0|
# |   15.27|     2500|  60|    C|          RENT|     30000|               car|         2.0|             0.0|           6.0|
# |   15.96|     2400|  36|    C|          RENT|     12252|    small_business|         2.0|             0.0|           5.0|
# |   13.49|    10000|  36|    C|          RENT|     49200|             other|         2.0|             0.0|           2.0|
# |   12.69|     3000|  60|    B|          RENT|     80000|             other|         0.0|             0.0|           2.0|
# |     7.9|     5000|  36|    A|          RENT|     36000|           wedding|         1.0|             0.0|           7.0|
# |   15.96|     7000|  60|    C|          RENT|     47004|debt_consolidation|         2.0|             0.0|           0.0|
# |   18.64|     3000|  36|    E|          RENT|     48000|               car|         4.0|             0.0|           6.0|
# |   21.28|     5600|  60|    F|           OWN|     40000|    small_business|         5.0|             2.0|           5.0|
# |   12.69|     5375|  60|    B|          RENT|     15000|             other|         0.0|             0.0|           2.0|
# |   14.65|     6500|  60|    C|           OWN|     72000|debt_consolidation|         2.0|             2.0|           0.0|
# |   12.69|    12000|  36|    B|           OWN|     75000|debt_consolidation|         0.0|             2.0|           0.0|
# |   13.49|     9000|  36|    C|          RENT|     30000|debt_consolidation|         2.0|             0.0|           0.0|
# |    9.91|     3000|  36|    B|          RENT|     15000|       credit_card|         0.0|             0.0|           1.0|
# |   10.65|    10000|  36|    B|          RENT|    100000|             other|         0.0|             0.0|           2.0|
# |   16.29|     1000|  36|    D|          RENT|     28000|debt_consolidation|         3.0|             0.0|           0.0|
# |   15.27|    10000|  36|    C|          RENT|     42000|  home_improvement|         2.0|             0.0|           3.0|
# |    6.03|     3600|  36|    A|      MORTGAGE|    110000|    major_purchase|         1.0|             1.0|           4.0|
# |   11.71|     6000|  36|    B|      MORTGAGE|     84000|           medical|         0.0|             1.0|           8.0|
# |    6.03|     9200|  36|    A|          RENT|     77385|debt_consolidation|         1.0|             0.0|           0.0|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+
# only showing top 20 rows

# %%
# from pyspark.sql.types import IntegerType,FloatType
# df = df.withColumn("int_rate", df["int_rate"].cast(FloatType()))
# df = df.withColumn("loan_amnt", df["loan_amnt"].cast(IntegerType()))
# df = df.withColumn("term", df["term"].cast(IntegerType()))
# df = df.withColumn("annual_inc", df["annual_inc"].cast(IntegerType()))
df_indexed2.printSchema()
# Out:
# root
#  |-- int_rate: float (nullable = true)
#  |-- loan_amnt: integer (nullable = true)
#  |-- term: integer (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: integer (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- gradeNumeric: double (nullable = false)
#  |-- ownershipNumeric: double (nullable = false)
#  |-- purposeNumeric: double (nullable = false)

# %%
from pyspark.ml.feature import OneHotEncoder
encoder = OneHotEncoder(inputCols=['ownershipNumeric'], outputCols=['ownershipOneHot'])
encoder_fitted = encoder.fit(df_indexed2)
encoder_data = encoder_fitted.transform(df_indexed2)
encoder_data.show()
# Out:
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+---------------+
# |int_rate|loan_amnt|term|grade|home_ownership|annual_inc|           purpose|gradeNumeric|ownershipNumeric|purposeNumeric|ownershipOneHot|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+---------------+
# |   10.65|     5000|  36|    B|          RENT|     24000|       credit_card|         0.0|             0.0|           1.0|  (4,[0],[1.0])|
# |   15.27|     2500|  60|    C|          RENT|     30000|               car|         2.0|             0.0|           6.0|  (4,[0],[1.0])|
# |   15.96|     2400|  36|    C|          RENT|     12252|    small_business|         2.0|             0.0|           5.0|  (4,[0],[1.0])|
# |   13.49|    10000|  36|    C|          RENT|     49200|             other|         2.0|             0.0|           2.0|  (4,[0],[1.0])|
# |   12.69|     3000|  60|    B|          RENT|     80000|             other|         0.0|             0.0|           2.0|  (4,[0],[1.0])|
# |     7.9|     5000|  36|    A|          RENT|     36000|           wedding|         1.0|             0.0|           7.0|  (4,[0],[1.0])|
# |   15.96|     7000|  60|    C|          RENT|     47004|debt_consolidation|         2.0|             0.0|           0.0|  (4,[0],[1.0])|
# |   18.64|     3000|  36|    E|          RENT|     48000|               car|         4.0|             0.0|           6.0|  (4,[0],[1.0])|
# |   21.28|     5600|  60|    F|           OWN|     40000|    small_business|         5.0|             2.0|           5.0|  (4,[2],[1.0])|
# |   12.69|     5375|  60|    B|          RENT|     15000|             other|         0.0|             0.0|           2.0|  (4,[0],[1.0])|
# |   14.65|     6500|  60|    C|           OWN|     72000|debt_consolidation|         2.0|             2.0|           0.0|  (4,[2],[1.0])|
# |   12.69|    12000|  36|    B|           OWN|     75000|debt_consolidation|         0.0|             2.0|           0.0|  (4,[2],[1.0])|
# |   13.49|     9000|  36|    C|          RENT|     30000|debt_consolidation|         2.0|             0.0|           0.0|  (4,[0],[1.0])|
# |    9.91|     3000|  36|    B|          RENT|     15000|       credit_card|         0.0|             0.0|           1.0|  (4,[0],[1.0])|
# |   10.65|    10000|  36|    B|          RENT|    100000|             other|         0.0|             0.0|           2.0|  (4,[0],[1.0])|
# |   16.29|     1000|  36|    D|          RENT|     28000|debt_consolidation|         3.0|             0.0|           0.0|  (4,[0],[1.0])|
# |   15.27|    10000|  36|    C|          RENT|     42000|  home_improvement|         2.0|             0.0|           3.0|  (4,[0],[1.0])|
# |    6.03|     3600|  36|    A|      MORTGAGE|    110000|    major_purchase|         1.0|             1.0|           4.0|  (4,[1],[1.0])|
# |   11.71|     6000|  36|    B|      MORTGAGE|     84000|           medical|         0.0|             1.0|           8.0|  (4,[1],[1.0])|
# |    6.03|     9200|  36|    A|          RENT|     77385|debt_consolidation|         1.0|             0.0|           0.0|  (4,[0],[1.0])|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+---------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import OneHotEncoder
encoder1 = OneHotEncoder(inputCols=['purposeNumeric'], outputCols=['purposeOneHot'])
encoder_fitted1 = encoder1.fit(encoder_data)
encoder_data1 = encoder_fitted1.transform(encoder_data)
encoder_data1.show()
# Out:
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+---------------+--------------+
# |int_rate|loan_amnt|term|grade|home_ownership|annual_inc|           purpose|gradeNumeric|ownershipNumeric|purposeNumeric|ownershipOneHot| purposeOneHot|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+---------------+--------------+
# |   10.65|     5000|  36|    B|          RENT|     24000|       credit_card|         0.0|             0.0|           1.0|  (4,[0],[1.0])|(13,[1],[1.0])|
# |   15.27|     2500|  60|    C|          RENT|     30000|               car|         2.0|             0.0|           6.0|  (4,[0],[1.0])|(13,[6],[1.0])|
# |   15.96|     2400|  36|    C|          RENT|     12252|    small_business|         2.0|             0.0|           5.0|  (4,[0],[1.0])|(13,[5],[1.0])|
# |   13.49|    10000|  36|    C|          RENT|     49200|             other|         2.0|             0.0|           2.0|  (4,[0],[1.0])|(13,[2],[1.0])|
# |   12.69|     3000|  60|    B|          RENT|     80000|             other|         0.0|             0.0|           2.0|  (4,[0],[1.0])|(13,[2],[1.0])|
# |     7.9|     5000|  36|    A|          RENT|     36000|           wedding|         1.0|             0.0|           7.0|  (4,[0],[1.0])|(13,[7],[1.0])|
# |   15.96|     7000|  60|    C|          RENT|     47004|debt_consolidation|         2.0|             0.0|           0.0|  (4,[0],[1.0])|(13,[0],[1.0])|
# |   18.64|     3000|  36|    E|          RENT|     48000|               car|         4.0|             0.0|           6.0|  (4,[0],[1.0])|(13,[6],[1.0])|
# |   21.28|     5600|  60|    F|           OWN|     40000|    small_business|         5.0|             2.0|           5.0|  (4,[2],[1.0])|(13,[5],[1.0])|
# |   12.69|     5375|  60|    B|          RENT|     15000|             other|         0.0|             0.0|           2.0|  (4,[0],[1.0])|(13,[2],[1.0])|
# |   14.65|     6500|  60|    C|           OWN|     72000|debt_consolidation|         2.0|             2.0|           0.0|  (4,[2],[1.0])|(13,[0],[1.0])|
# |   12.69|    12000|  36|    B|           OWN|     75000|debt_consolidation|         0.0|             2.0|           0.0|  (4,[2],[1.0])|(13,[0],[1.0])|
# |   13.49|     9000|  36|    C|          RENT|     30000|debt_consolidation|         2.0|             0.0|           0.0|  (4,[0],[1.0])|(13,[0],[1.0])|
# |    9.91|     3000|  36|    B|          RENT|     15000|       credit_card|         0.0|             0.0|           1.0|  (4,[0],[1.0])|(13,[1],[1.0])|
# |   10.65|    10000|  36|    B|          RENT|    100000|             other|         0.0|             0.0|           2.0|  (4,[0],[1.0])|(13,[2],[1.0])|
# |   16.29|     1000|  36|    D|          RENT|     28000|debt_consolidation|         3.0|             0.0|           0.0|  (4,[0],[1.0])|(13,[0],[1.0])|
# |   15.27|    10000|  36|    C|          RENT|     42000|  home_improvement|         2.0|             0.0|           3.0|  (4,[0],[1.0])|(13,[3],[1.0])|
# |    6.03|     3600|  36|    A|      MORTGAGE|    110000|    major_purchase|         1.0|             1.0|           4.0|  (4,[1],[1.0])|(13,[4],[1.0])|
# |   11.71|     6000|  36|    B|      MORTGAGE|     84000|           medical|         0.0|             1.0|           8.0|  (4,[1],[1.0])|(13,[8],[1.0])|
# |    6.03|     9200|  36|    A|          RENT|     77385|debt_consolidation|         1.0|             0.0|           0.0|  (4,[0],[1.0])|(13,[0],[1.0])|
# +--------+---------+----+-----+--------------+----------+------------------+------------+----------------+--------------+---------------+--------------+
# only showing top 20 rows

# %%
cols= ["grade","home_ownership"," purpose","ownershipNumeric","purposeNumeric"]
encoder_data1.drop(*cols).printSchema()
# Out:
# root
#  |-- int_rate: float (nullable = true)
#  |-- loan_amnt: integer (nullable = true)
#  |-- term: integer (nullable = true)
#  |-- annual_inc: integer (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- gradeNumeric: double (nullable = false)
#  |-- ownershipOneHot: vector (nullable = true)
#  |-- purposeOneHot: vector (nullable = true)

# %%
import pandas as pd
from pandas.plotting import scatter_matrix

numeric_features = [t[0] for t in encoder_data1.dtypes if t[1] == 'int' or t[1] == 'double']
sampled_data = encoder_data1.select(numeric_features).sample(False, 0.8).toPandas()
axs = pd.plotting.scatter_matrix(sampled_data, figsize=(10, 10))
n = len(sampled_data.columns)
for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n-1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())

# %%
import six
for i in encoder_data1.columns:
    if not( isinstance(encoder_data1.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to int_rate for ", i, encoder_data1.stat.corr('int_rate',i))
# Out:
# Correlation to int_rate for  int_rate 1.0
# Correlation to int_rate for  loan_amnt 0.31048061154458356
# Correlation to int_rate for  term 0.45288430934663326
# Correlation to int_rate for  annual_inc 0.05348537726567628
# Correlation to int_rate for  gradeNumeric 0.7575581154263259
# Correlation to int_rate for  ownershipNumeric -0.06276004998015378
# Correlation to int_rate for  purposeNumeric -0.08831817369733778
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <command-1231047598254670> in <module>
#       2 for i in encoder_data1.columns:
#       3     if not( isinstance(encoder_data1.select(i).take(1)[0][0], six.string_types)):
# ----> 4         print( "Correlation to int_rate for ", i, encoder_data1.stat.corr('int_rate',i))
#
# /databricks/spark/python/pyspark/sql/dataframe.py in corr(self, col1, col2, method)
#    3016
#    3017     def corr(self, col1, col2, method=None):
# -> 3018         return self.df.corr(col1, col2, method)
#    3019
#    3020     corr.__doc__ = DataFrame.corr.__doc__
#
# /databricks/spark/python/pyspark/sql/dataframe.py in corr(self, col1, col2, method)
#    2504             raise ValueError("Currently only the calculation of the Pearson Correlation " +
#    2505                              "coefficient is supported.")
# -> 2506         return self._jdf.stat().corr(col1, col2, method)
#    2507
#    2508     def cov(self, col1, col2):
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# IllegalArgumentException: requirement failed: Currently correlation calculation for columns with dataType struct<type:tinyint,size:int,indices:array<int>,values:array<double>> not supported.

# %%
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols = ['loan_amnt', 'term', 'annual_inc', 'gradeNumeric', 'ownershipNumeric', 'purposeNumeric'], outputCol = 'features')
vhouse_df = vectorAssembler.transform(encoder_data1)
vhouse_df = vhouse_df.select(['features', 'int_rate'])
vhouse_df.show(3)
# Out:
# +--------------------+--------+
# |            features|int_rate|
# +--------------------+--------+
# |[5000.0,36.0,2400...|   10.65|
# |[2500.0,60.0,3000...|   15.27|
# |[2400.0,36.0,1225...|   15.96|
# +--------------------+--------+
# only showing top 3 rows

# %%
splits = vhouse_df.randomSplit([0.7, 0.3])
train_df = splits[0]
test_df = splits[1]

# %%
from pyspark.ml.regression import LinearRegression
lr = LinearRegression(featuresCol = 'features', labelCol='int_rate', maxIter=10, regParam=0.3, elasticNetParam=0.8)
lr_model = lr.fit(train_df)
print("Coefficients: " + str(lr_model.coefficients))
print("Intercept: " + str(lr_model.intercept))
# Out:
# Coefficients: [2.603778889830644e-05,0.052064474394157144,0.0,1.6176738561094468,0.0,0.0]
# Intercept: 7.057249304127937

# %%
trainingSummary = lr_model.summary
print("RMSE: %f" % trainingSummary.rootMeanSquaredError)
print("r2: %f" % trainingSummary.r2)
# Out:
# RMSE: 2.320104
# r2: 0.611014

# %%
train_df.describe().show()
# Out:
# +-------+------------------+
# |summary|          int_rate|
# +-------+------------------+
# |  count|             27947|
# |   mean|  12.0399333851689|
# | stddev|3.7200444881963532|
# |    min|              5.42|
# |    max|             24.59|
# +-------+------------------+

# %%
lr_predictions = lr_model.transform(test_df)
lr_predictions.select("prediction","int_rate","features").show(5)
from pyspark.ml.evaluation import RegressionEvaluator
lr_evaluator = RegressionEvaluator(predictionCol="prediction", \
                 labelCol="int_rate",metricName="r2")
print("R Squared (R2) on test data = %g" % lr_evaluator.evaluate(lr_predictions))
# Out:
# +------------------+--------+--------------------+
# |        prediction|int_rate|            features|
# +------------------+--------+--------------------+
# |12.179936988985641|   11.41|[500.0,36.0,19500...|
# |12.190352104544964|   10.28|[900.0,36.0,12000...|
# |   8.9576081712159|    9.64|[1000.0,36.0,5000...|
# |12.192955883434795|   13.98|[1000.0,36.0,1176...|
# |12.192955883434795|   14.65|[1000.0,36.0,1182...|
# +------------------+--------+--------------------+
# only showing top 5 rows
#
# R Squared (R2) on test data = 0.614372

# %%
test_result = lr_model.evaluate(test_df)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result.rootMeanSquaredError)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.32547

# %%
print("numIterations: %d" % trainingSummary.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary.objectiveHistory))
trainingSummary.residuals.show()
# Out:
# numIterations: 9
# objectiveHistory: [0.5, 0.4296575226898259, 0.25499822310827924, 0.25156655964124963, 0.250701945264225, 0.25069772749551344, 0.25069748254130214, 0.2506974803358174, 0.2506974803039446, 0.25069748030292943]
# /databricks/spark/python/pyspark/sql/context.py:134: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# +-------------------+
# |          residuals|
# +-------------------+
# | 1.7654107613802257|
# |-2.4922634380519746|
# | 1.5154107613802257|
# |  0.815410952115089|
# |0.10485541508772656|
# | -3.198121749819231|
# |0.10355352564280906|
# | -3.200074583986604|
# |-1.9426781339945975|
# | 0.8036939471108511|
# | -0.945281912884429|
# |  2.067044345447041|
# | 2.1823921721068533|
# | 2.4023914854613455|
# | 1.0423918287840994|
# | 2.1823921721068533|
# | -2.085282256207183|
# | 1.4123917143431814|
# | 0.9293700315739226|
# | 1.2370444217409862|
# +-------------------+
# only showing top 20 rows

# %%
predictions = lr_model.transform(test_df)
predictions.select("prediction","int_rate","features").show()
# Out:
# +------------------+--------+--------------------+
# |        prediction|int_rate|            features|
# +------------------+--------+--------------------+
# |12.179936988985641|   11.41|[500.0,36.0,19500...|
# |12.190352104544964|   10.28|[900.0,36.0,12000...|
# |   8.9576081712159|    9.64|[1000.0,36.0,5000...|
# |12.192955883434795|   13.98|[1000.0,36.0,1176...|
# |12.192955883434795|   14.65|[1000.0,36.0,1182...|
# |12.192955883434795|   13.98|[1000.0,36.0,1200...|
# |13.810629739544241|   16.32|[1000.0,36.0,1200...|
# |10.575282027325347|     8.9|[1000.0,36.0,1248...|
# |13.810629739544241|    14.3|[1000.0,36.0,1500...|
# |13.810629739544241|   15.65|[1000.0,36.0,1600...|
# |12.192955883434795|   14.65|[1000.0,36.0,1840...|
# |12.192955883434795|   14.26|[1000.0,36.0,2000...|
# |13.810629739544241|   14.84|[1000.0,36.0,2229...|
# |   8.9576081712159|    9.99|[1000.0,36.0,2400...|
# |13.810629739544241|   14.91|[1000.0,36.0,2400...|
# |10.575282027325347|    7.51|[1000.0,36.0,2500...|
# |   8.9576081712159|   10.99|[1000.0,36.0,2640...|
# |   8.9576081712159|   11.49|[1000.0,36.0,2760...|
# |   8.9576081712159|   10.25|[1000.0,36.0,2800...|
# |   8.9576081712159|    9.63|[1000.0,36.0,2817...|
# +------------------+--------+--------------------+
# only showing top 20 rows

# %%
from pyspark.ml.regression import RandomForestRegressor
dt = RandomForestRegressor(featuresCol ='features', labelCol = 'int_rate')
dt_model = dt.fit(train_df)
dt_predictions = dt_model.transform(test_df)
dt_evaluator = RegressionEvaluator(
    labelCol="int_rate", predictionCol="prediction", metricName="rmse")
rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 1.2358

# %%
dt_evaluator1 = RegressionEvaluator(
    labelCol="int_rate", predictionCol="prediction", metricName="r2")
r2 = dt_evaluator1.evaluate(dt_predictions)
print("R2 on test data = %g" % r2)
# Out:
# R2 on test data = 0.891095

# %%
dt_evaluator2 = RegressionEvaluator(
    labelCol="int_rate", predictionCol="prediction", metricName="mse")
mse = dt_evaluator2.evaluate(dt_predictions)
print("MSE on test data = %g" % mse)
# Out:
# MSE on test data = 1.52721

# %%
dt_evaluator3 = RegressionEvaluator(
    labelCol="int_rate", predictionCol="prediction", metricName="mae")
mae = dt_evaluator3.evaluate(dt_predictions)
print("MAE on test data = %g" % mae)
# Out:
# MAE on test data = 0.950887

# %%
dt_model.featureImportances
# Out:
# Out[40]: SparseVector(6, {0: 0.0441, 1: 0.0939, 2: 0.0019, 3: 0.8453, 4: 0.0054, 5: 0.0094})
